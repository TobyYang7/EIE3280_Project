# %%
import json
import time

from operator import itemgetter
from seoanalyzer.website import Website


def analyze(url, sitemap_url=None, analyze_headings=False, analyze_extra_tags=False, follow_links=True):
    start_time = time.time()

    def calc_total_time():
        return time.time() - start_time

    output = {'pages': [], 'keywords': [],
              'errors': [], 'total_time': calc_total_time()}

    site = Website(url, sitemap_url, analyze_headings,
                   analyze_extra_tags, follow_links)

    site.crawl()

    for p in site.crawled_pages:
        output['pages'].append(p.talk())

    output['duplicate_pages'] = [list(site.content_hashes[p])
                                 for p in site.content_hashes if len(site.content_hashes[p]) > 1]

    sorted_words = sorted(site.wordcount.items(),
                          key=itemgetter(1), reverse=True)
    sorted_bigrams = sorted(site.bigrams.items(),
                            key=itemgetter(1), reverse=True)
    sorted_trigrams = sorted(site.trigrams.items(),
                             key=itemgetter(1), reverse=True)

    output['keywords'] = []

    print('sorted_words')
    for w in sorted_words:
        if w[1] > 4:
            output['keywords'].append({
                'word': w[0],
                'count': w[1],
            })

    print('sorted_bigrams')
    for w, v in sorted_bigrams:
        if v > 4:
            output['keywords'].append({
                'word': w,
                'count': v,
            })

    print('sorted_trigrams')
    for w, v in sorted_trigrams:
        if v > 4:
            output['keywords'].append({
                'word': w,
                'count': v,
            })

    # Sort one last time...
    output['keywords'] = sorted(
        output['keywords'], key=itemgetter('count'), reverse=True)

    output['total_time'] = calc_total_time()

    return output

# %%
output = analyze('https://staff.ie.cuhk.edu.hk/~jwhuang/')
# Out:
# sorted_words
# sorted_bigrams
# sorted_trigrams

# %%
for i in output:
    print(i, output[i])

print(output['pages'][0])

for i in output['pages'][0]:
    print(i, output['pages'][0][i])
# Out:
# pages [{'url': 'https://staff.ie.cuhk.edu.hk/~jwhuang/', 'title': 'jianwei huang @ cuhk', 'description': '', 'word_count': 1080, 'keywords': [(32, 'ieee'), (29, 'university'), (27, 'awards'), (18, 'research'), (16, 'engineering'), (14, 'paper'), (14, 'communications'), (13, 'professor'), (12, 'young'), (12, 'science'), (12, 'ncel'), (12, 'best'), (11, 'network'), (11, 'dr'), (11, 'chinese'), (11, '2015'), (10, 'kong'), (10, 'hong'), (10, 'cuhk'), (10, '2016'), (9, 'news'), (9, 'editor'), (9, 'department'), (8, 'received'), (7, 'transactions'), (7, 'shenzhen'), (7, 'information'), (7, 'comsoc'), (7, 'computer'), (7, 'associate'), (7, '2018'), (7, '2017'), (6, 'technology'), (6, 'phd'), (6, 'economics'), (5, 'society'), (5, 'professional'), (5, 'opening'), (5, 'daily')], 'bigrams': Counter({'university of': 16, 'paper award': 11, 'hong kong': 10, 'best paper': 10, 'department of': 9, 'engineering the': 7, 'the chinese': 7, 'chinese university': 7, 'of hong': 7, 'transactions on': 7, 'i
# ...
