# %%
import json
import time

from operator import itemgetter
from seoanalyzer.website import Website


def analyze(url, sitemap_url=None, analyze_headings=False, analyze_extra_tags=False, follow_links=True):
    start_time = time.time()

    def calc_total_time():
        return time.time() - start_time

    output = {'pages': [], 'keywords': [],
              'errors': [], 'total_time': calc_total_time()}

    site = Website(url, sitemap_url, analyze_headings,
                   analyze_extra_tags, follow_links)

    site.crawl()

    for p in site.crawled_pages:
        output['pages'].append(p.talk())

    output['duplicate_pages'] = [list(site.content_hashes[p])
                                 for p in site.content_hashes if len(site.content_hashes[p]) > 1]

    sorted_words = sorted(site.wordcount.items(),
                          key=itemgetter(1), reverse=True)
    sorted_bigrams = sorted(site.bigrams.items(),
                            key=itemgetter(1), reverse=True)
    sorted_trigrams = sorted(site.trigrams.items(),
                             key=itemgetter(1), reverse=True)

    output['keywords'] = []

    print('sorted_words')
    for w in sorted_words:
        if w[1] > 4:
            output['keywords'].append({
                'word': w[0],
                'count': w[1],
            })

    print('sorted_bigrams')
    for w, v in sorted_bigrams:
        if v > 4:
            output['keywords'].append({
                'word': w,
                'count': v,
            })

    print('sorted_trigrams')
    for w, v in sorted_trigrams:
        if v > 4:
            output['keywords'].append({
                'word': w,
                'count': v,
            })

    # Sort one last time...
    output['keywords'] = sorted(
        output['keywords'], key=itemgetter('count'), reverse=True)

    output['total_time'] = calc_total_time()

    return output

# %%
output = analyze('https://tobyyang7.github.io/')
# Out:
# sorted_words
# sorted_bigrams
# sorted_trigrams

# %%
for i in output:
    print(i, output[i])
# Out:
# pages [{'url': 'https://tobyyang7.github.io/', 'title': 'academicpages is a ready-to-fork github pages template for academic personal websites - your name / site title', 'description': '', 'word_count': 131, 'keywords': [(6, 'github')], 'bigrams': Counter({'this is': 4, 'your name': 3, 'is my': 3, 'homepage https': 3, 'academicpages is': 2, 'is ready': 2, 'ready to': 2, 'to fork': 2, 'fork github': 2, 'github pages': 2, 'pages template': 2, 'template for': 2, 'for academic': 2, 'academic personal': 2, 'personal websites': 2, 'name site': 2, 'site title': 2, 'com tobyyang7': 2, 'websites your': 1, 'title your': 1, 'title publications': 1, 'publications talks': 1, 'talks teaching': 1, 'teaching portfolio': 1, 'portfolio blog': 1, 'blog posts': 1, 'posts cv': 1, 'cv guide': 1, 'guide your': 1, 'your sidebar': 1, 'sidebar name': 1, 'name your': 1, 'your biography': 1, 'biography for': 1, 'for the': 1, 'the left': 1, 'left hand': 1, 'hand sidebar': 1, 'sidebar follow': 1, 'follow location': 1, 'location twitter': 1, 'twitter github': 1, 'github google': 1, 'google scholar': 1, 'scholar pubmed': 1, 'pubmed orcid': 1, 'orcid academicpages': 1, 'websites hello': 1, 'hello this': 1, 'is toby': 1, 'toby yang': 1, 'yang homepages': 1, 'homepages junior': 1, 'junior student': 1, 'student in': 1, 'in the': 1, 'the school': 1, 'school of': 1, 'of science': 1, 'science and': 1, 'and data': 1, 'data science': 1, 'science the': 1, 'the chinese': 1, 'chinese university': 1, 'university of': 1, 'of hongkong': 1, 'hongkong shenzhen': 1, 'shenzhen this': 1, 'my instagram': 1, 'instagram homepage': 1, 'https www': 1, 'www instagram': 1, 'instagram com': 1, 'tobyyang7 this': 1, 'my unsplash': 1, 'unsplash homepage': 1, 'https unsplash': 1, 'unsplash com': 1, 'com tobyyang': 1, 'tobyyang where': 1, 'where you': 1, 'you could': 1, 'could find': 1, 'find more': 1, 'more high': 1, 'high quality': 1, 'quality images': 1, 'images this': 1, 'my github': 1, 'github homepage': 1, 'https github': 1, 'github com': 1, 'tobyyang7 sitemap': 1, 'sitemap follow': 1, 'follow github': 1, 'github feed': 1, 'feed 2023': 1, '2023 your': 1, 'name powered': 1, 'powered by': 1, 'by jekyll': 1, 'jekyll academicpages': 1, 'academicpages fork': 1, 'fork of': 1, 'of minimal': 1, 'minimal mistakes': 1}), 'trigrams': Counter({'this is my': 3, 'academicpages is ready': 2, 'is ready to': 2, 'ready to fork': 2, 'to fork github': 2, 'fork github pages': 2, 'github pages template': 2, 'pages template for': 2, 'template for academic': 2, 'for academic personal': 2, 'academic personal websites': 2, 'your name site': 2, 'name site title': 2, 'personal websites your': 1, 'websites your name': 1, 'site title your': 1, 'title your name': 1, 'site title publications': 1, 'title publications talks': 1, 'publications talks teaching': 1, 'talks teaching portfolio': 1, 'teaching portfolio blog': 1, 'portfolio blog posts': 1, 'blog posts cv': 1, 'posts cv guide': 1, 'cv guide your': 1, 'guide your sidebar': 1, 'your sidebar name': 1, 'sidebar name your': 1, 'name your biography': 1, 'your biography for': 1, 'biography for the': 1, 'for the left': 1, 'the left hand': 1, 'left hand sidebar': 1, 'hand sidebar follow': 1, 'sidebar follow location': 1, 'follow location twitter': 1, 'location twitter github': 1, 'twitter github google': 1, 'github google scholar': 1, 'google scholar pubmed': 1, 'scholar pubmed orcid': 1, 'pubmed orcid academicpages': 1, 'orcid academicpages is': 1, 'personal websites hello': 1, 'websites hello this': 1, 'hello this is': 1, 'this is toby': 1, 'is toby yang': 1, 'toby yang homepages': 1, 'yang homepages junior': 1, 'homepages junior student': 1, 'junior student in': 1, 'student in the': 1, 'in the school': 1, 'the school of': 1, 'school of science': 1, 'of science and': 1, 'science and data': 1, 'and data science': 1, 'data science the': 1, 'science the chinese': 1, 'the chinese university': 1, 'chinese university of': 1, 'university of hongkong': 1, 'of hongkong shenzh ...
# keywords [{'word': 'post', 'count': 30}, {'word': 'blog', 'count': 20}, {'word': 'number', 'count': 20}, {'word': 'this is', 'count': 13}, {'word': 'blog post', 'count': 13}, {'word': 'github', 'count': 12}, {'word': 'publish', 'count': 12}, {'word': 'test', 'count': 12}, {'word': 'page', 'count': 10}, {'word': 'titl', 'count': 10}, {'word': 'talk', 'count': 10}, {'word': 'paper', 'count': 9}, {'word': 'your name', 'count': 9}, {'word': 'academicpag', 'count': 8}, {'word': 'teach', 'count': 8}, {'word': 'portfolio', 'count': 8}, {'word': 'lorem', 'count': 8}, {'word': 'ipsum', 'count': 8}, {'word': 'lorem ipsum', 'count': 8}, {'word': 'testing testing', 'count': 8}, {'word': 'markdown', 'count': 7}, {'word': 'blog posts', 'count': 7}, {'word': 'http', 'count': 6}, {'word': 'futur', 'count': 6}, {'word': 'descript', 'count': 6}, {'word': 'journal', 'count': 6}, {'word': 'field', 'count': 6}, {'word': 'description of', 'count': 6}, {'word': 'paper title', 'count': 6}, {'word': 'title number', 'count': 6}, {'word': 'the number', 'count': 6}, {'word': 'paper title number', 'count': 6}, {'word': 'fork', 'count': 5}, {'word': 'site', 'count': 5}, {'word': 'left', 'count': 5}, {'word': 'sitemap', 'count': 5}, {'word': 'minut', 'count': 5}, {'word': 'read', 'count': 5}, {'word': '01', 'count': 5}, {'word': 'less than', 'count': 5}, {'word': 'than minute', 'count': 5}, {'word': 'minute read', 'count': 5}, {'word': 'read published', 'count': 5}, {'word': 'less than minute', 'count': 5}, {'word': 'than minute read', 'count': 5}, {'word': 'minute read published', 'count': 5}]
# errors []
# total_time 0.8615560531616211
# duplicate_pages []
